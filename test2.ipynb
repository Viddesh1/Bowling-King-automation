# %%
print("Hello the world of GPU")
# !pip list
# Out:
# Hello the world of GPU
# Package                   Version
# ------------------------- ------------
# anyio                     4.0.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.2.3
# asttokens                 2.4.0
# async-lru                 2.0.4
# attrs                     23.1.0
# Babel                     2.12.1
# backcall                  0.2.0
# beautifulsoup4            4.12.2
# bleach                    6.0.0
# certifi                   2023.7.22
# cffi                      1.15.1
# charset-normalizer        3.2.0
# cmake                     3.27.4.1
# colorama                  0.4.6
# comm                      0.1.4
# contourpy                 1.1.0
# cryptography              41.0.3
# cycler                    0.11.0
# debugpy                   1.8.0
# decorator                 5.1.1
# defusedxml                0.7.1
# exceptiongroup            1.1.3
# executing                 1.2.0
# ...
